# %%
import pandas as pd

# %%
data = pd.read_csv("fathersonheight.csv")
data
# Out:
#       Father   Son
# 0       65.0  59.8
# 1       63.3  63.2
# 2       65.0  63.3
# 3       65.8  62.8
# 4       61.1  64.3
# ...      ...   ...
# 1073    67.0  70.8
# 1074    71.3  68.3
# 1075    71.8  69.3
# 1076    70.7  69.3
# 1077    70.3  67.0
#
# [1078 rows x 2 columns]

# %%
x = data['Father'].values.reshape(-1,1)
y = data['Son'].values.reshape(-1,1)

# %%
from sklearn.linear_model import LinearRegression
lin_reg = LinearRegression()
lin_reg.fit(x,y)
# Out:
# LinearRegression()

# %%
import matplotlib.pyplot as plt
plt.scatter(x,y,color='blue')
plt.plot(x,lin_reg.predict(x),color='red')
plt.title('Father Height vs Son Height')
plt.xlabel('Father Height')
plt.ylabel('Son Height')
plt.show()

# %%
print(x," "," predicted age:",lin_reg.predict(x))
# Out:
# [[65. ]
#  [63.3]
#  [65. ]
#  ...
#  [71.8]
#  [70.7]
#  [70.3]]    predicted age: [[67.30318486]
#  [66.4293748 ]
#  [67.30318486]
#  ...
#  [70.79842506]
#  [70.23301856]
#  [70.02741619]]

# %%
from sklearn.metrics import mean_squared_error
print("accuracy of the model is:",mean_squared_error(y,lin_reg.predict(x)))
# Out:
# accuracy of the model is: 5.933470496211082

# %%
from sklearn.preprocessing import PolynomialFeatures

poly = PolynomialFeatures(degree = 3)
x_poly = poly.fit_transform(x,y)
poly.fit(x_poly, y)

lin_reg_poly = LinearRegression()
lin_reg_poly.fit(x_poly, y)
# Out:
# LinearRegression()

# %%
import matplotlib.pyplot as plt

plt.scatter(x, y, color = 'blue')
plt.plot(x, lin_reg_poly.predict(poly.fit_transform(x)), color = 'red', linewidth=3)
plt.title('Father Height vs Son Height')
plt.xlabel('Father Height')
plt.ylabel('Son Height')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[35], line 3
#       1 import matplotlib.pyplot as plt
# ----> 3 plt.scatter(x, y, color = 'blue')
#       4 plt.plot(x, lin_reg_poly.predict(poly.fit_transform(x)), color = 'red', linewidth=3)
#       5 plt.title('Father Height vs Son Height')
#
# File ~\anaconda3\lib\site-packages\matplotlib\pyplot.py:2835, in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, data, **kwargs)
#    2830 @_copy_docstring_and_deprecators(Axes.scatter)
#    2831 def scatter(
#    2832         x, y, s=None, c=None, marker=None, cmap=None, norm=None,
#    2833         vmin=None, vmax=None, alpha=None, linewidths=None, *,
#    2834         edgecolors=None, plotnonfinite=False, data=None, **kwargs):
# -> 2835     __ret = gca().scatter(
# ...
